# %%
# import the required modules
import cv2
import matplotlib.pyplot as plt
from deepface import DeepFace

# %%
img = cv2.imread('C:/Users/91639/Downloads/img1.jpg')

# %%
# call imshow() using plt object
plt.imshow(img[:,:,::-1])

# %%
# display that image
plt.show()

# %%
# storing the result
result = DeepFace.analyze(img,actions=['emotion'])

# print result
print(result)
# Out:
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00,  1.43it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.11it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.69it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.35it/s]
# [{'emotion': {'angry': 0.018197152530774474, 'disgust': 8.88002291057205e-11, 'fear': 93.9418077468872, 'happy': 0.7629166822880507, 'sad': 4.90494966506958, 'surprise': 0.006165167724248022, 'neutral': 0.3659656969830394}, 'dominant_emotion': 'fear', 'region': {'x': 3676, 'y': 2727, 'w': 125, 'h': 125}}, {'emotion': {'angry': 1.6244444101717717, 'disgust': 0.0001548914020995316, 'fear': 0.0012611624539672836, 'happy': 95.57985041021409, 'sad': 2.5918962116179594, 'surprise': 1.3640825460665963e-05, 'neutral': 0.2023833458801118}, 'dominant_emotion': 'happy', 'region': {'x': 2406, 'y': 5094, 'w': 485, 'h': 485}}, {'emotion': {'angry': 1.0635434352483413, 'disgust': 5.935372014601435e-06, 'fear': 3.0385006167590984, 'happy': 67.75264547781023, 'sad': 18.410838747670574, 'surprise': 0.10904333971326588, 'neutral': 9.625423528279276}, 'dominant_emotion': 'happy', 'region': {'x': 1393, 'y': 4554, 'w': 81, 'h': 81}}, {'emotion': {'angry': 0.14163718704579395, 'disgust': 2.9205091642765986e-06, 'fear': 3.4412400985503258, 'happy': 0.02868953331944545, 'sad': 20.55091086333459, 'surprise': 0.0001480664738698437, 'neutral': 75.83737229331567}, 'dominant_emotion': 'neutral', 'region': {'x': 2718, 'y': 233, 'w': 158, 'h': 158}}]
